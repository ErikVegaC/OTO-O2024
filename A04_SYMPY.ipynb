# %% [markdown]
# <a href="https://colab.research.google.com/github/ErikVegaC/OTO-O2024/blob/main/A04_SYMPY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simulación matemática - A04_SYMPY

# %% [markdown]
# ### Erik Gabriel Vega Cervantes a 29 de agosto de 2023

# %% [markdown]
# #### Resuelve los siguientes ejercicios:
#
# 1. Utiliza sympy y encuentra los valores de las incógnitas que hagan que los siguientes sistemas de ecuaciones sean verdaderos

# %% [markdown]
# - 1.1 $$ x + y = 10 $$  $$ x - y = 2 $$
#
#
#
# - 1.2 $$ \frac{3x - 2y}{3} + 4y = \frac{13}{3} $$ $$ \frac{2(-2y + x)}{3} - \frac{3x}{2} = - \frac{13}{6} $$
#
# - 1.3 $$ x^2 - 2y = 16  $$ $$ x-y = 3 $$
#
# - 1.4 $$ x + y - z = 10 $$ $$ x - y = 2 $$ $$ y + z = - 2 $$

# %%
# Primer sistema de ecuaciones 1.1

import sympy as sp

sp.var("x")
sp.var("y")

eq1 = x + y - 10
eq2 = x - y - 2

x_eq1 = sp.solve(eq1,x)[0]

y_eq2 = eq2.subs(x,x_eq1)

y_sol = sp.solve(y_eq2,y)[0]

x_sol = x_eq1.subs(y,y_sol)

print("X es igual a " +str(x_sol))
print("Y es igual a " +str(y_sol))
# Out:
# X es igual a 6
# Y es igual a 4

# %%
# Segundo sistema de ecuaciones 1.2

import sympy as sp
sp.var("x")
sp.var("y")

eq1_2 = (((3*x)-(2*y))/3) + (4*y) - (13/3)
eq2_2 = ((2*((-2*y)+ x))/3) - ((3*x)/2) + (13/6)

x_eq1_2 = sp.solve(eq1_2,x)[0]
y_eq2_2 = eq2_2.subs(x,x_eq1_2)

y_sol_2 = sp.solve(y_eq2_2,y)[0]
x_sol_2 = x_eq1_2.subs(y,y_sol_2)

print("X es igual a " +str(x_sol_2))
print("Y es igual a " +str(y_sol_2))
# Out:
# X es igual a 1.00000000000000
# Y es igual a 1.00000000000000

# %%
# Tercer sistema de ecuaciones 1.3

import sympy as sp

sp.var("x")
sp.var("y")

eq1_3_0 = x**2 - 2*y - 16
eq2_3_0 = x - y - 3

# SOLVE X[0]

x_eq1_3_0 = sp.solve(eq1_3_0,x)[0]
y_eq2_3_0 = eq2_3_0.subs(x,x_eq1_3_0)

y_sol_3_0 = sp.solve(y_eq2_3_0,y)[0]
x_sol_3_0 = x_eq1_3_0.subs(y,y_sol_3_0)

print("X es igual a " +str(x_sol_3_0))
print("Y es igual a " +str(y_sol_3_0))

# SOLVE X[1]


eq1_3_1 = (x**2) - (2*y) - 16
eq2_3_1 = (x - y - 3)

x_eq1_3_1 = sp.solve(eq1_3_1,x)[1]
y_eq2_3_1 = eq2_3_1.subs(x,x_eq1_3_1)

y_sol_3_1 = sp.solve(y_eq2_3_1,y)[0]
x_sol_3_1 = x_eq1_3_1.subs(y,y_sol_3_1)

print("X es igual a " +str(x_sol_3_1))
print("Y es igual a " +str(y_sol_3_1))
# Out:
# X es igual a -sqrt(12 - 2*sqrt(11))
# Y es igual a -sqrt(11) - 2
# X es igual a sqrt(2*sqrt(11) + 12)
# Y es igual a -2 + sqrt(11)

# %%
# Cuarto sistema de ecuaciones 1.4

import sympy as sp

sp.var("x")
sp.var("y")
sp.var("z")


eq1_4 = x + y - z -10
eq2_4 = x - y -  2
eq3_4 = y + z + 2

x_eq2_4 = sp.solve(eq2_4,x)[0]
x_eq1_4 = eq1_4.subs(x,x_eq2_4)
z_solve = x_eq1_4.subs(y,y_eq3_4)

val_z = sp.solve(z_solve,z)[0]

y_solve = eq3_4.subs(z,val_z)

val_y = sp.solve(y_solve,y)[0]


x_solve_1 = eq1_4.subs(y,val_y)
x_solve_2 = x_solve_1.subs(z,val_z)

val_x = sp.solve(x_solve_2,x)[0]

print("X es igual a " +str(val_x))
print("Y es igual a " +str(val_y))
print("Z es igual a " +str(val_z))
# Out:
# X es igual a 4
# Y es igual a 2
# Z es igual a -4

# %% [markdown]
# 2. Encuentra los puntos críticos usando cálculo diferencial, decide si son máximos o mínimos usando el criterio de la segunda derivada, y grafica para decidir se son óptimos locales o globales:

# %% [markdown]
#  - $ f(x) = 1235 + 113x - 6x^2 $
#  - $ f(x) = - 3 + x + \frac{π}{x} $ , para $ x > 0 $
#  - $ f(x) = 2 - 3x + \sqrt{8 - 2x^2} $ , para $ -2 \leq x \leq 2 $
#  - $ f(x) = \frac{1}{4}x^4 + \frac{1}{3}x^3 - x^2 $ en el intervalo $ [- 3, 1.7 ] $

# %% [markdown]
# Puntos a considerar:
#
#    - Las ecuaciones deben estar transcritas en Markdown con el formato correcto.
#    - Los puntos críticos en las gráficas deben estar marcados.

# %%
# Ecuación 2.1

import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

sp.var("x")
sp.var("y")

def f2_1(x) :
    return 1235 + 113*x - 6*(x**2)

diff_f2_1 = sp.diff(f2_1(x),x)
solve_f2_1 = sp.solve(diff_f2_1,x)[0]
diff2_f2_1 = sp.diff(f2_1(x),x,2)

# Ecuación 2.2

def f2_2(x) :
  return -3 + x + (sp.pi/x)

diff_f2_2 = sp.diff(f2_2(x),x)
solve_f2_2 = sp.solve(diff_f2_2,x)[1]
diff2_f2_2 = sp.diff(f2_2(x),x,2)
subsdiff2_f2_2 = diff2_f2_2.subs(x,solve_f2_2)

# Ecuación 2.3

def f2_3(x) :
   return sp.sqrt(8-(2*(x**2)))-3*x + 2

diff_f2_3 = sp.diff(f2_3(x),x)
solve_f2_3 = sp.solve(diff_f2_3,x)[0]
diff2_f2_3 = sp.diff(f2_3(x),x,2)
subsdiff2_f2_3 = diff2_f2_3.subs(x,solve_f2_3)


# Ecuación 2.4

def f2_4(x) :
  return ((1/4)*(x**4))+((1/3)*(x**3))-(x**2)

diff_f2_4 = sp.diff(f2_4(x),x)
solve_f2_4_0 = sp.solve(diff_f2_4,x)[0]
solve_f2_4_1 = sp.solve(diff_f2_4,x)[1]
solve_f2_4_2 = sp.solve(diff_f2_4,x)[2]

diff2_f2_4 = sp.diff(f2_4(x),x,2)

subsdiff2_f2_4_0 = diff2_f2_4.subs(x,solve_f2_4_0)
subsdiff2_f2_4_1 = diff2_f2_4.subs(x,solve_f2_4_1)
subsdiff2_f2_4_2 = diff2_f2_4.subs(x,solve_f2_4_2)


print(f"El punto critico de la ecuación numero 1 es : ({float(solve_f2_1)} , {float(f2_1(solve_f2_1))})")
print(f"    Tomando en cuenta la segunda derivada de la función que es {diff2_f2_1}, se considera un máximo" )
print(f"El punto crítico de la ecuacion numero 2 para x > 0 es :  ({float(solve_f2_2)} , {float(f2_2(solve_f2_2))})")
print(f"    Tomando en cuenta la segunda derivada de la función que es {diff2_f2_2} y sustituyendo en la misma con el valor del punto crítico en 'x', en 'y' : {float(subsdiff2_f2_2)}")
print(f"    Como 'y' es mayor a 0 se considera un mínimo relativo, debido a que tiene otra solución")
print(f"El punto crítico de la ecuación numero 3 en el intervalo [-2,2] es :  ({float(solve_f2_3)} , {float(f2_3(solve_f2_3))})")
print(f"    Tomando en cuenta la segunda derivada de la funcion que es {diff2_f2_3} y sustituyendo en la misma con el valor del punto crítico en 'x', en 'y' : {float(subsdiff2_f2_3)}")
print(f"    Como 'y' es menor a 0 se considera un máximo absoluto ya que no tiene más soluciones")
print(f"El primer punto crítico de la ecuacion numero 4 para el intervalo [-3,1.7] en x es :  ({solve_f2_4_0} , {f2_4(solve_f2_4_0)})")
print(f"    Tomando en cuenta la segunda derivada de la función que es {diff2_f2_4} y sustituyendo en la misma con el valor del punto crítico en 'x', en 'y' : {float(subsdiff2_f2_4_0)}")
print(f"    Como 'y' es mayor a 0 se considera un minimo absoluto ya que no hay valores menores a esta primera solución")
print(f"El segundo punto crítico de la ecuacion numero 4 para el intervalo [-3,1.7] en x es :  ({solve_f2_4_1} , {f2_4(solve_f2_4_1)})")
print(f"    Tomando en cuenta la segunda derivada de la función que es {diff2_f2_4} y sustituyendo en la misma con el valor del punto crítico en 'x', en 'y' : {float(subsdiff2_f2_4_1)}")
print(f"    Como 'y' es menor a 0 se considera un máximo relativo debido a que la parábola tiene un rango infinito  ")
print(f"El tercer punto crítico de la ecuacion numero 4 para el intervalo [-3,1.7] en x es :  ({solve_f2_4_2} , {f2_4(solve_f2_4_2)})")
print(f"    Tomando en cuenta la segunda derivada de la función que es {diff2_f2_4} y sustituyendo en la misma con el valor del punto crítico en 'x', en 'y' : {float(subsdiff2_f2_4_2)}")
print(f"    Como 'y' es mayor a 0 se considera un mínimo relativo ya que la primera solución sustituída en la función es menor a ésta solución  ")




# No es chatGPT la neta si le eché ganas jajaj
# Out:
# El punto critico de la ecuación numero 1 es : (9.416666666666666 , 1767.0416666666667)
#     Tomando en cuenta la segunda derivada de la función que es -12, se considera un máximo
# El punto crítico de la ecuacion numero 2 para x > 0 es :  (1.772453850905516 , 0.5449077018110321)
#     Tomando en cuenta la segunda derivada de la función que es 2*pi/x**3 y sustituyendo en la misma con el valor del punto crítico en 'x', en 'y' : 1.1283791670955126
#     Como 'y' es mayor a 0 se considera un mínimo relativo, debido a que tiene otra solución
# El punto crítico de la ecuación numero 3 en el intervalo [-2,2] es :  (-1.8090680674665818 , 8.6332495807108)
#     Tomando en cuenta la segunda derivada de la funcion que es -sqrt(2)*(x**2/(4 - x**2) + 1)/sqrt(4 - x**2) y sustituyendo en la misma con el valor del punto crítico en 'x', en 'y' : -9.12071817347735
#     Como 'y' es menor a 0 se considera un máximo absoluto ya que no tiene más soluciones
# ...

# %%
y1 = 1235 + 113*x - 6*(x**2)
y2 = (-3) + (x) + ((np.pi)/x)
y3 = ((8-(2*(x**2)))**(1/2))-3*x + 2
y4 = ((1/4)*(x**4))+((1/3)*(x**3))-(x**2)

x = np.linspace(-100,100,10000)


plt.figure(figsize=(10,5))
plt.title("Función 1")
plt.plot(x,y1)
plt.plot(solve_f2_1,f2_1(solve_f2_1),marker="o",color="red")
plt.xlim(-10,20)
plt.ylim(-1000,2500)
plt.grid()


plt.xlabel("x")
plt.ylabel("y")


plt.figure(figsize=(10,5))
plt.title("Función 2")
plt.plot(x,y2)
plt.plot(solve_f2_2,f2_2((solve_f2_2)),marker="o",color="red")
plt.xlim(-5,5)
plt.ylim(-3,3)
plt.grid()


plt.xlabel("x")
plt.ylabel("y")


plt.figure(figsize=(10,5))
plt.title("Función 3")
plt.plot(x,y3)
plt.plot(solve_f2_3,f2_3((solve_f2_3)),marker="o",color="red")
plt.xlim(-3,3)
plt.ylim(-10,10)
plt.grid()


plt.xlabel("x")
plt.ylabel("y")


plt.figure(figsize=(10,5))
plt.title("Función 4")
plt.plot(x,y4)
plt.plot(solve_f2_4_0,f2_4((solve_f2_4_0)),marker="o",color="red")
plt.plot(solve_f2_4_1,f2_4((solve_f2_4_1)),marker="o",color="red")
plt.plot(solve_f2_4_2,f2_4((solve_f2_4_2)),marker="o",color="red")
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.grid()

plt.xlabel("x")
plt.ylabel("y")
# Out:
# <ipython-input-132-9c4b34d75895>:3: RuntimeWarning: invalid value encountered in sqrt
#   y3 = ((8-(2*(x**2)))**(1/2))-3*x + 2
# Text(0, 0.5, 'y')
