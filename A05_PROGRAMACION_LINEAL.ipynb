# %% [markdown]
# <a href="https://colab.research.google.com/github/ErikVegaC/OTO-O2024/blob/main/A05_PROGRAMACION_LINEAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simulación matemática - A05_Programación_lineal

# %% [markdown]
# #### Erik Gabriel Vega Cervantes a 05 de septiembre de 2024

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# 1. Identificar problema de optimización
#   - Costo mínimo
#   - Cumplir con los datos requeridos de análisis nutricional
# 2. Variables de control
#   - Pollo "P"
#   - Carne "C"
#   - Cordero "CO"
#   - Arroz "A"
#   - Trigo "T"
#   - Gel "G"
# 3. Función de costo
#
# $$ f(P,C,CO,A,T,G) =  0.012\frac{$}{g} P + 0.009\frac{$}{g} C + 0.010 \frac{$}{g}CO + 0.003\frac{$}{g} A + 0.005 \frac{$}{g}T + 0.002\frac{$}{g}G  $$
#
# 4. Información adicional
#
# - En 100 gramos:
#
#   - Mayor o igual a 9 gramos de proteína
#   - Mayor o igual a 7 gramos de grasa
#   - Menor o igual a 2.5 gramos de fibra
#   - Menor o igual a 0.5 gramos de sal
#
#
# $$ 0.1P + 0.2C + 0.15CO + 0.04T \geq 9   $$
# $$ 0.08P + 0.1C + 0.11CO + 0.01A + 0.01T \geq 7 $$
# $$ 0.001P + 0.005C + 0.005CO + 0.1A + 0.15T \leq 2.5 $$
# $$ 0.002P + 0.005C + 0.007CO + 0.002A + 0.008T \leq 0.5  $$
# $$ P + C + CO + A + T + G = 100  $$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Identificar problema de optimización
#   -
#
# 2. Variables de control
#   - Planta 1 -  $ P_1 $
#   - Planta 2 -  $ P_2 $
#   - Planta 3 -  $ P_3 $
#
# 3. Función de costo \\
#   $ f(P_1, P_2, P_3) = P_1(13 \frac{$}{MW}) + P_2P_1(8 \frac{$}{MW}) + P_3(15 \frac{$}{MW}) $
# 4. Información adicional
#   - Guadalajara = 60 millones de kW al dia
#   - León = 45 millones de kW al dia
#   - Morelia = 60 millones de kW al dia
#
#       - $ 5P_1 + 3P_2 + 5P_3 = 60  $
#       - $ 2P_1 + 4P_2 + 2P_3 = 45  $
#       - $ 7P_1 + 5P_2 + 3P_3 = 60  $
