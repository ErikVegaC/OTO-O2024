# %% [markdown]
# # **Simulación Matemática - Erik Gabriel Vega Cervantes 745264**

# %% [markdown]
# ## T01 - Markdown

# %% [markdown]
# ### Teoría del esfuerzo normal

# %% [markdown]
# Para empezar a entender lo que es un esfuerzo normal, tenemos que definirla como un aplastamiento o un tensionamiento, lo cual lo vemos en la vida cotidiana cuando tensionamos un cable, cuando aplicamos fuerza al cuchillo para cortar una verdura o simplemente cuando estamos caminando.

# %% [markdown]
# Esta teoría aplica para todo lo que está en equilibrio y lo que está en movimiento, se define como una fuerza sobre una área en la que tiene efecto.
#
# *"Fuerza por unidad de superficie que soporta ó se aplica sobre un cuerpo, es decir es la relación entre la fuerza aplicada y la superficie en la cual se aplica" - Egor Popov*

# %% [markdown]
# Se representa con la siguiente ecuación:

# %% [markdown]
# $$ Esfuerzo = \frac{Fuerza}{Área} $$

# %% [markdown]
# ![](https://www.researchgate.net/profile/Santander-Leon/publication/325229715/figure/fig2/AS:627746791256064@1526677906804/Figura-3-formula-de-esfuerzo-normal-sometido-a-una-fuerza-P-con-un-area-transversal-A.png )

# %% [markdown]
# Podemos enlistar los usos de esta fórmula tales como:
#
#     1. Equilibrio de vigas
#     2. Diseño de estructuras de concreto y acero
#     3. Prueba de especímenes para determinar la calidad de un concreto
#     4. Calidad de cables de acero que se someten a tensión en una grúa
#
# Donde no aplica esta fórmula se consideran casos anormales debido a su rara aparición en la construcción, tales como:
#
#     * Perfiles de sección variable
#     * Análisis de movimento de tierra trepidatorio (3 ejes)
#     * Elementos que se someten gravemente a flujo de cortatnte

# %% [markdown]
# En el ámbito de la ingenieria civil esta teoría es usada el 95% de los casos para diseñar estructuras en las cuales estas se sometene a esfuerzos normales, ya sea de tensión o de compresión, en cambio, en el resto de los casos se llegan a usar programas en el cual se usan sistemas de matrices o elemento finito para aproximar un resultado debido a perfiles de sección variable principalmente
# .
